# %% [markdown]
# # Analyse Query Results: Detect Versions vs Unique Resources

# %% [markdown]
# When you get query results in SolrWayback, it will provide archival resources that matches your query.
#
# However, you might want to know how many of them that are unique, and how many that are different versions of the same resource.
#
# Different versions are not necessarily duplicates. For a front page of a web news site, there will be great dissimilarities from one day to the next. However, when you use SolrWayback to define a corpus of resources for examination, it might be valuable to know if some of resources in your corpus are "overrepresented" due to a high number of versions.
#
# This notebook let you analyse the number of unique urls in the corpus, and detect which archived urls that appears several times.
#
# #### JSONL data from SolrWayback
# You will need a file in JSONL format, exported from your SolrWayback query result. The notebook uses an example from a query on "Jonas Gahr Støre", but you can replace this data from your own queries.
#
# For the operations in this notebook to work, the fields "warc_key_id", "url_norm" and "crawl_date" must be included in the export.

# %% [markdown]
# ### Import libraries

# %% [markdown]
# First, we need to import the necessary libraries.

# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /Users/joncto/opt/anaconda3/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/joncto/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/joncto/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/joncto/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /Users/joncto/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in /Users/joncto/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ### Load data from SolrWayback

# %% [markdown]
# Then, we load the JSONL data set you exported from SolrWayback.

# %%
df = pd.read_json('data/solrwayback_JonasGahrStore.jsonl', lines=True)
display(df)
# Out:
#                                           warc_key_id  \
# 0     <urn:uuid:06add8d3-380a-4b3a-9cf5-2578f77d7f62>
# 1     <urn:uuid:8de22051-ee5a-4d25-b7eb-0c1d48f1e007>
# 2     <urn:uuid:db2fb7a5-0eb1-460e-b414-e77fa2d2b410>
# 3     <urn:uuid:498cd143-f833-4c6c-aec6-fc721e25bc88>
# 4     <urn:uuid:d65a4fb6-b316-480e-842c-d644d6c1ad49>
# ...                                               ...
# 6408  <urn:uuid:0647b30d-bcbe-4537-a95f-a6a0ce5aaffa>
# 6409  <urn:uuid:fc1b7067-c8ba-434d-bb85-5184ac83914f>
# 6410  <urn:uuid:f916850c-9474-4da1-8229-7bc507112d27>
# 6411  <urn:uuid:ba5c7751-2470-4d77-acb9-c955b3da8f0d>
# 6412  <urn:uuid:2ca44f98-06cd-4115-8b32-9885af6358e6>
#
#                                     title            domain  \
# 0     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# 1     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# 2     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# 3     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# 4     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# ...                                   ...               ...
# 6408                                  NaN            tv2.no
# 6409                                  NaN            tv2.no
# 6410                                  NaN            tv2.no
# 6411                                  NaN             vl.no
# 6412                                  NaN     dagsavisen.no
#
#                content_type     crawl_date  crawl_year  \
# 0     application/xhtml+xml  1645812529000        2022
# 1     application/xhtml+xml  1646070193000        2022
# 2     application/xhtml+xml  1646330192000        2022
# 3     application/xhtml+xml  1646765196000        2022
# 4     application/xhtml+xml  1646919904000        2022
# ...                     ...            ...         ...
# 6408             text/plain  1646061800000        2022
# 6409             text/plain  1646323954000        2022
# 6410             text/plain  1648824785000        2022
# 6411             text/plain  1685060661000        2023
# 6412             text/plain  1685091944000        2023
#
#                                                url_norm
# 0          http://europabloggen.no/tag/jonas-gahr-støre
# 1          http://europabloggen.no/tag/jonas-gahr-støre
# 2          http://europabloggen.no/tag/jonas-gahr-støre
# 3          http://europabloggen.no/tag/jonas-gahr-støre
# 4          http://europabloggen.no/tag/jonas-gahr-støre
# ...                                                 ...
# 6408  http://tv2.no:443/spesialer/api/open/articles/...
# 6409  http://tv2.no:443/spesialer/api/open/articles/...
# 6410  http://tv2.no:443/spesialer/api/open/articles/...
# 6411  http://vl.no:443/pf/api/v3/content/fetch/conte...
# 6412  http://dagsavisen.no:443/pf/api/v3/content/fet...
#
# [6413 rows x 7 columns]

# %% [markdown]
# ## 1. Convert timestamp

# %% [markdown]
# The timestamps in our JSONL file is in the machine-readable Unix format. Before computing this, we want to convert it into python's Datetime format

# %%
df['crawl_date'] = pd.to_datetime(df['crawl_date'], unit='ms')
display(df)
# Out:
#                                           warc_key_id  \
# 0     <urn:uuid:06add8d3-380a-4b3a-9cf5-2578f77d7f62>
# 1     <urn:uuid:8de22051-ee5a-4d25-b7eb-0c1d48f1e007>
# 2     <urn:uuid:db2fb7a5-0eb1-460e-b414-e77fa2d2b410>
# 3     <urn:uuid:498cd143-f833-4c6c-aec6-fc721e25bc88>
# 4     <urn:uuid:d65a4fb6-b316-480e-842c-d644d6c1ad49>
# ...                                               ...
# 6408  <urn:uuid:0647b30d-bcbe-4537-a95f-a6a0ce5aaffa>
# 6409  <urn:uuid:fc1b7067-c8ba-434d-bb85-5184ac83914f>
# 6410  <urn:uuid:f916850c-9474-4da1-8229-7bc507112d27>
# 6411  <urn:uuid:ba5c7751-2470-4d77-acb9-c955b3da8f0d>
# 6412  <urn:uuid:2ca44f98-06cd-4115-8b32-9885af6358e6>
#
#                                     title            domain  \
# 0     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# 1     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# 2     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# 3     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# 4     Europabloggen.no » Jonas Gahr Støre  europabloggen.no
# ...                                   ...               ...
# 6408                                  NaN            tv2.no
# 6409                                  NaN            tv2.no
# 6410                                  NaN            tv2.no
# 6411                                  NaN             vl.no
# 6412                                  NaN     dagsavisen.no
#
#                content_type          crawl_date  crawl_year  \
# 0     application/xhtml+xml 2022-02-25 18:08:49        2022
# 1     application/xhtml+xml 2022-02-28 17:43:13        2022
# 2     application/xhtml+xml 2022-03-03 17:56:32        2022
# 3     application/xhtml+xml 2022-03-08 18:46:36        2022
# 4     application/xhtml+xml 2022-03-10 13:45:04        2022
# ...                     ...                 ...         ...
# 6408             text/plain 2022-02-28 15:23:20        2022
# 6409             text/plain 2022-03-03 16:12:34        2022
# 6410             text/plain 2022-04-01 14:53:05        2022
# 6411             text/plain 2023-05-26 00:24:21        2023
# 6412             text/plain 2023-05-26 09:05:44        2023
#
#                                                url_norm
# 0          http://europabloggen.no/tag/jonas-gahr-støre
# 1          http://europabloggen.no/tag/jonas-gahr-støre
# 2          http://europabloggen.no/tag/jonas-gahr-støre
# 3          http://europabloggen.no/tag/jonas-gahr-støre
# 4          http://europabloggen.no/tag/jonas-gahr-støre
# ...                                                 ...
# 6408  http://tv2.no:443/spesialer/api/open/articles/...
# 6409  http://tv2.no:443/spesialer/api/open/articles/...
# 6410  http://tv2.no:443/spesialer/api/open/articles/...
# 6411  http://vl.no:443/pf/api/v3/content/fetch/conte...
# 6412  http://dagsavisen.no:443/pf/api/v3/content/fet...
#
# [6413 rows x 7 columns]

# %% [markdown]
# ### 1. Count resources (unique urls and urls with several versions)

# %% [markdown]
# Let us count the number each url appear.

# %%
url_counts = df['url_norm'].value_counts()

# %% [markdown]
# Then, we want to filter urls that appears more than one time in the data set.
# To make it easier to read, we limit the dataframe to the url, title and count columns.
# Then, we display a table with

# %%
urls_with_multiple_timestamps = df.groupby('url_norm').filter(lambda x: x['crawl_date'].nunique() > 1)
urls_with_counts = urls_with_multiple_timestamps.groupby(['url_norm', 'title'])['crawl_date'].nunique().reset_index(name='versions')
urls_with_counts = urls_with_counts.sort_values(by='versions', ascending=False)

# Print summary message
total_rows = df.shape[0]
unique_urls = len(df['url_norm'].unique())
multiple_versions = len(urls_with_counts)
print(f"Total number of lines in the dataset: \033[1m{total_rows}\033[0m \nNumber of unique resources: \033[1m{unique_urls}\033[0m \nNumber of resources archived in several versions: \033[1m{multiple_versions}\033[0m.")

display(urls_with_counts)
# Out:
# Total number of lines in the dataset: 6413
# Number of unique resources: 3482
# Number of resources archived in several versions: 979.
#                                               url_norm  \
# 898               http://sapmi.arbeiderpartiet.no:443/
# 189                            http://friheten.no:443/
# 901  http://sapmi.arbeiderpartiet.no:443/l/se/polit...
# 907     http://sapmi.arbeiderpartiet.no:443/nyhetsbrev
# 0                     http://abcnyheter.no:443/hvordan
# ..                                                 ...
# 743  http://regjeringen.no:443/no/aktuelt/taler_art...
# 237  http://nettavisen.no:443/norsk-debatt/tenk-om-...
# 238  http://nettavisen.no:443/nyheter/blir-det-krig...
# 88   http://dagbladet.no:443/nyheter/tidslinje-russ...
# 159  http://folkogforsvar.no:443/ukraina-vestens-re...
#
#                                                  title  versions
# 898                                           Forsiden        25
# 189                                           artikkel        10
# 901                          Válggaprogramma 2021-2025         9
# 907                 Få nyhetsbrev fra Arbeiderpartiet!         8
# 0                                Hvordan | ABC Nyheter         7
# ..                                                 ...       ...
# 743                  Taler og innlegg - regjeringen.no         2
# 237  Norsk politikk, Ukraina | Tenk om Moxnes og Ly...         2
# 238  Ukraina, Russland | Blir det krig i Norge? Det...         2
# 88               Tidslinje: Russlands krig mot Ukraina         1
# 159                           Ukraina: Vestens respons         1
#
# [979 rows x 3 columns]
